# %%
import pandas as pd

# %%
df = pd.read_spss('data/45s3v77wzd-1/Datos Tesis Articulo Buffer.sav', convert_categoricals=False)

# %%
df.head()
# Out:
#    Identificador  AñoBajaLaboral  Sexo  Edad  ModoDeVida  CódigoResidencia  \
# 0       148704.0          2015.0   1.0  53.0         3.0               1.0
# 1       127968.0          2015.0   1.0  51.0         1.0              13.0
# 2        59072.0          2016.0   1.0  44.0         3.0              13.0
# 3       104498.0          2016.0   2.0  45.0         3.0              13.0
# 4        74105.0          2015.0   1.0  44.0         2.0              13.0
#
#    NivelEstudios  CargoQueOcupa  AntigüedadPuesto  ModallidadPago  ...  \
# 0            2.0            1.0               6.0             1.0  ...
# 1            4.0            1.0               5.0             1.0  ...
# 2            4.0            1.0               5.0             1.0  ...
# 3            3.0            1.0               4.0             1.0  ...
# 4            5.0            2.0               4.0             3.0  ...
#
#    DiagAnsVsDep  PreBAICentered  PrePIL20Centered  PrePIL20CxPreBAIc  \
# ...

# %%
df
# Out:
#      Identificador  AñoBajaLaboral  Sexo  Edad  ModoDeVida  CódigoResidencia  \
# 0         148704.0          2015.0   1.0  53.0         3.0               1.0
# 1         127968.0          2015.0   1.0  51.0         1.0              13.0
# 2          59072.0          2016.0   1.0  44.0         3.0              13.0
# 3         104498.0          2016.0   2.0  45.0         3.0              13.0
# 4          74105.0          2015.0   1.0  44.0         2.0              13.0
# ..             ...             ...   ...   ...         ...               ...
# 162        86978.0          2015.0   1.0  33.0         3.0              13.0
# 163       129184.0          2015.0   2.0  29.0         2.0              13.0
# 164       121947.0          2015.0   1.0  26.0         2.0              13.0
# 165        83547.0          2015.0   1.0  38.0         3.0              13.0
# 166        36917.0          2016.0   1.0  55.0         2.0              13.0
#
# ...
